# %% [markdown]
# <a href="https://colab.research.google.com/github/Yousef-Zeer/Prediction-of-Product-Sales/blob/main/Project_1_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prediction of Product Sales
#
#
# - Author: Yousef Al Zeer

# %% [markdown]
# ## Project Overview

# %% [markdown]
# ## Load and Inspect Data

# %% [markdown]
# ## Clean Data

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Feature Inspection
